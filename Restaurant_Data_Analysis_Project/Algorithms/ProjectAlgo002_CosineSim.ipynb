# %% [markdown]
# # Recommendation System

# %% [markdown]
# ## Simple Recommendation System

# %% [markdown]
# ### Importing Files

# %%
import numpy as np 
import pandas as pd 
import re

# %% [markdown]
# ### Loading Data

# %%
data = pd.read_csv('/home/student/Desktop/Practise_Folder/Project/Data/zomatoNCR.csv', encoding ='latin1')
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Extracting Delhi NCR Data

# %%
res_India = data
NCR = ['New Delhi','Gurgaon','Noida','Faridabad']
res_NCR = res_India[(res_India.City == NCR[0])|(res_India.City == NCR[1])|(res_India.City == NCR[2])|
                    (res_India.City == NCR[3])]

res_NCR.shape
# Out:
# (7922, 21)

# %% [markdown]
# ### Regularizing Predicting Parameters --(Rating and Voting)

# %%
data_new_delhi=res_NCR[['Restaurant Name','Cuisines','Locality','Aggregate rating', 'Votes']] #--Extracting Columns


C = data_new_delhi['Aggregate rating'].mean()
m = data_new_delhi['Votes'].quantile(0.90) #--Quantile

q_restaurant = data_new_delhi.copy().loc[data_new_delhi['Votes'] >= m]
q_restaurant.shape
# Out:
# (795, 5)

# %%
# Function that computes the weighted rating of each restaurant
def weighted_rating(x, m=m, C=C):
    v = x['Votes']
    R = x['Aggregate rating']
    return np.round((v/(v+m) * R) + (m/(m+v) * C))


q_restaurant['score'] = q_restaurant.apply(weighted_rating, axis=1)

# %%
#Sort restaurant based on score calculated above
#q_restaurant = q_restaurant.sort_values('score', ascending=False)
q_restaurant['score'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Output

# %%
#Print the top 10 restaurants in Delhi NCR
q_restaurant[['Restaurant Name','Cuisines', 'Locality','Votes', 'Aggregate rating', 'score']].head(10)
# Out:
#       Restaurant Name                                     Cuisines  \
# 884           Berco's                                Chinese, Thai
# 891   Barbeque Nation                                 North Indian
# 892         Yo! China                                      Chinese
# 943     Cafe Parmesan                                      Italian
# 949       Chickenette  Raw Meats, North Indian, Chinese, Fast Food
# 1163     Punjab Grill                        North Indian, Mughlai
# 1164           Zambar                South Indian, Seafood, Kerala
# 1190    Bisque Bakery                            Bakery, Fast Food
# 1209      Khyen Chyen                                     Kashmiri
# 1211          Tughlaq      North Indian, Mughlai, Chinese, Seafood
#
#                                         Locality  Votes  Aggregate rating  \
# 884   Crown Interiorz Mall, Sector 35, Faridabad    508               3.8
# 891   Crown Interiorz Mall, Sector 35, Faridabad    299               4.0
# 892   Crown Interiorz Mall, Sector 35, Faridabad    239               4.1
# 943                                    Sector 15    799               4.5
# 949                                    Sector 15    280               3.7
# 1163                      Ambience Mall, Gurgaon   1887               4.3
# 1164                      Ambience Mall, Gurgaon    802               4.0
# 1190        Central Arcade, DLF Phase 2, Gurgaon    415               3.9
# 1209               Cross Point Mall, DLF Phase 4    364               3.7
# 1211               Cross Point Mall, DLF Phase 4    351               3.5
#
#       score
# 884     3.0
# 891     3.0
# 892     3.0
# 943     4.0
# 949     3.0
# 1163    4.0
# 1164    4.0
# 1190    3.0
# 1209    3.0
# 1211    3.0

# %% [markdown]
# ## Content Based Algorithm

# %% [markdown]
# ### Importing Files

# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Loading Data

# %%
data = pd.read_csv('/home/student/Desktop/Practise_Folder/Project/Data/zomatoNCR.csv', encoding ='latin1')
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Extracting Relevant Columns

# %%
data_new_delhi=data[['Restaurant Name','Cuisines','Locality','Aggregate rating', 'Votes']]

# %%
data_sample=[]
data_sample = data_new_delhi.loc[data_new_delhi['Locality'] == 'Connaught Place']
data_sample.reset_index(level=0, inplace=True) 
data_sample.head()
# Out:
#    index         Restaurant Name  \
# 0   2999                   Amber
# 1   3000  Attitude Kitchen & Bar
# 2   3001         Cafe Coffee Day
# 3   3002                Castle 9
# 4   3003            Costa Coffee
#
#                                           Cuisines         Locality  \
# 0                   North Indian, Chinese, Mughlai  Connaught Place
# 1               North Indian, Continental, Italian  Connaught Place
# 2                                             Cafe  Connaught Place
# 3  Finger Food, Continental, North Indian, Chinese  Connaught Place
# 4                                             Cafe  Connaught Place
#
#    Aggregate rating  Votes
# 0               2.6    152
# 1               2.9    140
# 2               3.4    277
# 3               3.1   1099
# 4               3.4     76

# %% [markdown]
# ### Creating spearate column for Cusines

# %%
# Creating New Column
data_sample['Split']="X"
data_sample
# Out:
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      index             Restaurant Name  \
# 0     2999                       Amber
# 1     3000      Attitude Kitchen & Bar
# 2     3001             Cafe Coffee Day
# 3     3002                    Castle 9
# 4     3003                Costa Coffee
# 5     3004          Delhi Darbar Dhaba
# 6     3005                Garam Dharam
# 7     3006               Gola Sizzlers
# 8     3007         Indian Coffee House
# 9     3008  My Bar Lounge & Restaurant
# 10    3009               My Bar Square
# 11    3010                 Sagar Ratna
# 12    3011          The Immigrant Cafe
# 13    3012                 MOB Brewpub
# 14    3013          Naturals Ice Cream
# 15    3014    Zabardast Indian Kitchen
# 16    3015            Anand Restaurant
# 17    3016                     Berco's
# 18    3017                       Blues
# 19    3018                 Burger King
# 20    3019                Burger Singh
# 21    3020  Cafe Coffee Day The Square
# 22    3021           Cafe Dalal Street
# 23    3022                Cafe Hawkers
# 24    3023      Cafe Public Connection
# 25    3024                  Cafï¿½ MRP
# 26    3025                Caffe Tonino
# 27    3026                     Cha Bar
# 28    3027                     Chaayos
# 29    3028       Chew - Pan Asian Cafe
# ..     ...                         ...
# 92    3091   Shree Hari Vaishnav Dhaba
# 93    3092                 38 Barracks
# 94    3093              Ambrosia Bliss
# 95    3094                   Ardor 2.1
# 96    3095             Barbeque Nation
# 97    3096            Bikkgane Biryani
# 98    3097               Biryani Blues
# 99    3098                     Caffe 9
# 100   3099              Excuse Me Boss
# 101   3100                     Fa Yian
# 102   3101                  Farzi Cafe
# 103   3102    Fuji Japanese Restaurant
# 104   3103              Healthy Routes
# 105   3104                     HotMess
# 106   3105            House of Commons
# 107   3106              Johnny Rockets
# 108   3107                Odeon Social
# 109   3108               Pebble Street
# 110   3109    Piali - The Curry Bistro
# 111   3110             Saravana Bhavan
# 112   3111              Smoke On Water
# 113   3112                   Starbucks
# 114   3113     The Darzi Bar & Kitchen
# 115   3114               The G.T. Road
# 116   3115         The Town House Cafe
# 117   3116         United Coffee House
# 118   3117         Unplugged Courtyard
# 119   3118               Wenger's Deli
# 120   3119                    Wenger's
# 121   3120        {Niche} - Cafe & Bar
#
#                                               Cuisines         Locality  \
# 0                       North Indian, Chinese, Mughlai  Connaught Place
# 1                   North Indian, Continental, Italian  Connaught Place
# 2                                                 Cafe  Connaught Place
# 3      Finger Food, Continental, North Indian, Chinese  Connaught Place
# 4                                                 Cafe  Connaught Place
# 5                                North Indian, Chinese  Connaught Place
# 6                                         North Indian  Connaught Place
# 7          Chinese, North Indian, Mughlai, Continental  Connaught Place
# 8                                            Fast Food  Connaught Place
# 9          North Indian, Chinese, Italian, Continental  Connaught Place
# 10         North Indian, Chinese, Italian, Continental  Connaught Place
# 11                 South Indian, North Indian, Chinese  Connaught Place
# 12                  North Indian, Italian, Continental  Connaught Place
# 13                 Continental, Italian, Asian, Indian  Connaught Place
# 14                                           Ice Cream  Connaught Place
# 15                                        North Indian  Connaught Place
# 16                                        North Indian  Connaught Place
# 17                                       Chinese, Thai  Connaught Place
# 18   Continental, Mexican, American, Italian, North...  Connaught Place
# 19                                   Burger, Fast Food  Connaught Place
# 20                         Burger, Juices, Finger Food  Connaught Place
# 21                                                Cafe  Connaught Place
# 22                              North Indian, European  Connaught Place
# 23                  Chinese, Continental, North Indian  Connaught Place
# 24                  North Indian, Continental, Italian  Connaught Place
# 25       North Indian, Chinese, Italian, Mediterranean  Connaught Place
# 26                                Pizza, Italian, Cafe  Connaught Place
# 27                                                Cafe  Connaught Place
# 28                                           Cafe, Tea  Connaught Place
# 29                      Asian, Japanese, Chinese, Thai  Connaught Place
# ..                                                 ...              ...
# 92                                        North Indian  Connaught Place
# 93              North Indian, Italian, Asian, American  Connaught Place
# 94         North Indian, Chinese, Italian, Continental  Connaught Place
# 95         North Indian, Chinese, Continental, Italian  Connaught Place
# 96                               North Indian, Chinese  Connaught Place
# 97                   Biryani, North Indian, Hyderabadi  Connaught Place
# 98                                 Biryani, Hyderabadi  Connaught Place
# 99   North Indian, Chinese, Italian, American, Midd...  Connaught Place
# 100  Continental, North Indian, Chinese, Mediterranean  Connaught Place
# 101                                            Chinese  Connaught Place
# 102                                      Modern Indian  Connaught Place
# 103                                           Japanese  Connaught Place
# 104                 Healthy Food, Continental, Italian  Connaught Place
# 105      North Indian, Mediterranean, Asian, Fast Food  Connaught Place
# 106  Continental, Mediterranean, Italian, North Indian  Connaught Place
# 107                        Fast Food, American, Burger  Connaught Place
# 108         Continental, American, Asian, North Indian  Connaught Place
# 109  Italian, Mexican, Continental, North Indian, F...  Connaught Place
# 110                                Asian, North Indian  Connaught Place
# 111                                       South Indian  Connaught Place
# 112  Continental, Mexican, Burger, American, Pizza,...  Connaught Place
# 113                                               Cafe  Connaught Place
# 114                             North Indian, European  Connaught Place
# 115                     North Indian, Afghani, Mughlai  Connaught Place
# 116          Continental, North Indian, Italian, Asian  Connaught Place
# 117       North Indian, European, Asian, Mediterranean  Connaught Place
# 118                          North Indian, Continental  Connaught Place
# 119                        Bakery, Desserts, Fast Food  Connaught Place
# 120                        Bakery, Fast Food, Desserts  Connaught Place
# 121        North Indian, Chinese, Italian, Continental  Connaught Place
#
#      Aggregate rating  Votes Split
# 0                 2.6    152     X
# 1                 2.9    140     X
# 2                 3.4    277     X
# 3                 3.1   1099     X
# 4                 3.4     76     X
# 5                 3.2     89     X
# 6                 3.4   1523     X
# 7                 3.0    671     X
# 8                 3.3   1300     X
# 9                 2.7   2460     X
# 10                2.5   1096     X
# 11                3.4    499     X
# 12                3.2    563     X
# 13                4.7     52     X
# 14                4.9   2620     X
# 15                4.7    242     X
# 16                3.6    485     X
# 17                3.9   2639     X
# 18                3.7    706     X
# 19                3.8   2093     X
# 20                3.6    548     X
# 21                3.6    361     X
# 22                3.7    873     X
# 23                3.7    673     X
# 24                3.7    834     X
# 25                3.6    877     X
# 26                3.9   1503     X
# 27                3.9   3206     X
# 28                3.9    487     X
# 29                3.9   2003     X
# ..                ...    ...   ...
# 92                0.0      2     X
# 93                4.4    840     X
# 94                4.0   2333     X
# 95                4.1   1821     X
# 96                4.1   3164     X
# 97                4.1    740     X
# 98                4.0    510     X
# 99                4.2    961     X
# 100               4.1    799     X
# 101               4.0    412     X
# 102               4.4   1942     X
# 103               4.0    312     X
# 104               4.0    361     X
# 105               4.3   1129     X
# 106               4.0    510     X
# 107               4.0    608     X
# 108               4.1   1959     X
# 109               4.0    817     X
# 110               4.1    400     X
# 111               4.3   5172     X
# 112               4.1    467     X
# 113               4.1   2417     X
# 114               4.1     90     X
# 115               4.3    104     X
# 116               4.0   2252     X
# 117               4.1   1838     X
# 118               4.0   1758     X
# 119               4.3   1457     X
# 120               4.3   3591     X
# 121               4.1    492     X
#
# [122 rows x 7 columns]

# %%
for i in range(0,data_sample.index[-1]):
        split_data=re.split(r'[,]', data_sample['Cuisines'][i])
        for k,l in enumerate(split_data):
            split_data[k]=(split_data[k].replace(" ", ""))
        split_data=' '.join(split_data[:])
        data_sample['Split'].iloc[i]=split_data
        
data_sample
# Out:
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      index             Restaurant Name  \
# 0     2999                       Amber
# 1     3000      Attitude Kitchen & Bar
# 2     3001             Cafe Coffee Day
# 3     3002                    Castle 9
# 4     3003                Costa Coffee
# 5     3004          Delhi Darbar Dhaba
# 6     3005                Garam Dharam
# 7     3006               Gola Sizzlers
# 8     3007         Indian Coffee House
# 9     3008  My Bar Lounge & Restaurant
# 10    3009               My Bar Square
# 11    3010                 Sagar Ratna
# 12    3011          The Immigrant Cafe
# 13    3012                 MOB Brewpub
# 14    3013          Naturals Ice Cream
# 15    3014    Zabardast Indian Kitchen
# 16    3015            Anand Restaurant
# 17    3016                     Berco's
# 18    3017                       Blues
# 19    3018                 Burger King
# 20    3019                Burger Singh
# 21    3020  Cafe Coffee Day The Square
# 22    3021           Cafe Dalal Street
# 23    3022                Cafe Hawkers
# 24    3023      Cafe Public Connection
# 25    3024                  Cafï¿½ MRP
# 26    3025                Caffe Tonino
# 27    3026                     Cha Bar
# 28    3027                     Chaayos
# 29    3028       Chew - Pan Asian Cafe
# ..     ...                         ...
# 92    3091   Shree Hari Vaishnav Dhaba
# 93    3092                 38 Barracks
# 94    3093              Ambrosia Bliss
# 95    3094                   Ardor 2.1
# 96    3095             Barbeque Nation
# 97    3096            Bikkgane Biryani
# 98    3097               Biryani Blues
# 99    3098                     Caffe 9
# 100   3099              Excuse Me Boss
# 101   3100                     Fa Yian
# 102   3101                  Farzi Cafe
# 103   3102    Fuji Japanese Restaurant
# 104   3103              Healthy Routes
# 105   3104                     HotMess
# 106   3105            House of Commons
# 107   3106              Johnny Rockets
# 108   3107                Odeon Social
# 109   3108               Pebble Street
# 110   3109    Piali - The Curry Bistro
# 111   3110             Saravana Bhavan
# 112   3111              Smoke On Water
# 113   3112                   Starbucks
# 114   3113     The Darzi Bar & Kitchen
# 115   3114               The G.T. Road
# 116   3115         The Town House Cafe
# 117   3116         United Coffee House
# 118   3117         Unplugged Courtyard
# 119   3118               Wenger's Deli
# 120   3119                    Wenger's
# 121   3120        {Niche} - Cafe & Bar
#
#                                               Cuisines         Locality  \
# 0                       North Indian, Chinese, Mughlai  Connaught Place
# 1                   North Indian, Continental, Italian  Connaught Place
# 2                                                 Cafe  Connaught Place
# 3      Finger Food, Continental, North Indian, Chinese  Connaught Place
# 4                                                 Cafe  Connaught Place
# 5                                North Indian, Chinese  Connaught Place
# 6                                         North Indian  Connaught Place
# 7          Chinese, North Indian, Mughlai, Continental  Connaught Place
# 8                                            Fast Food  Connaught Place
# 9          North Indian, Chinese, Italian, Continental  Connaught Place
# 10         North Indian, Chinese, Italian, Continental  Connaught Place
# 11                 South Indian, North Indian, Chinese  Connaught Place
# 12                  North Indian, Italian, Continental  Connaught Place
# 13                 Continental, Italian, Asian, Indian  Connaught Place
# 14                                           Ice Cream  Connaught Place
# 15                                        North Indian  Connaught Place
# 16                                        North Indian  Connaught Place
# 17                                       Chinese, Thai  Connaught Place
# 18   Continental, Mexican, American, Italian, North...  Connaught Place
# 19                                   Burger, Fast Food  Connaught Place
# 20                         Burger, Juices, Finger Food  Connaught Place
# 21                                                Cafe  Connaught Place
# 22                              North Indian, European  Connaught Place
# 23                  Chinese, Continental, North Indian  Connaught Place
# 24                  North Indian, Continental, Italian  Connaught Place
# 25       North Indian, Chinese, Italian, Mediterranean  Connaught Place
# 26                                Pizza, Italian, Cafe  Connaught Place
# 27                                                Cafe  Connaught Place
# 28                                           Cafe, Tea  Connaught Place
# 29                      Asian, Japanese, Chinese, Thai  Connaught Place
# ..                                                 ...              ...
# 92                                        North Indian  Connaught Place
# 93              North Indian, Italian, Asian, American  Connaught Place
# 94         North Indian, Chinese, Italian, Continental  Connaught Place
# 95         North Indian, Chinese, Continental, Italian  Connaught Place
# 96                               North Indian, Chinese  Connaught Place
# 97                   Biryani, North Indian, Hyderabadi  Connaught Place
# 98                                 Biryani, Hyderabadi  Connaught Place
# 99   North Indian, Chinese, Italian, American, Midd...  Connaught Place
# 100  Continental, North Indian, Chinese, Mediterranean  Connaught Place
# 101                                            Chinese  Connaught Place
# 102                                      Modern Indian  Connaught Place
# 103                                           Japanese  Connaught Place
# 104                 Healthy Food, Continental, Italian  Connaught Place
# 105      North Indian, Mediterranean, Asian, Fast Food  Connaught Place
# 106  Continental, Mediterranean, Italian, North Indian  Connaught Place
# 107                        Fast Food, American, Burger  Connaught Place
# 108         Continental, American, Asian, North Indian  Connaught Place
# 109  Italian, Mexican, Continental, North Indian, F...  Connaught Place
# 110                                Asian, North Indian  Connaught Place
# 111                                       South Indian  Connaught Place
# 112  Continental, Mexican, Burger, American, Pizza,...  Connaught Place
# 113                                               Cafe  Connaught Place
# 114                             North Indian, European  Connaught Place
# 115                     North Indian, Afghani, Mughlai  Connaught Place
# 116          Continental, North Indian, Italian, Asian  Connaught Place
# 117       North Indian, European, Asian, Mediterranean  Connaught Place
# 118                          North Indian, Continental  Connaught Place
# 119                        Bakery, Desserts, Fast Food  Connaught Place
# 120                        Bakery, Fast Food, Desserts  Connaught Place
# 121        North Indian, Chinese, Italian, Continental  Connaught Place
#
#      Aggregate rating  Votes  \
# 0                 2.6    152
# 1                 2.9    140
# 2                 3.4    277
# 3                 3.1   1099
# 4                 3.4     76
# 5                 3.2     89
# 6                 3.4   1523
# 7                 3.0    671
# 8                 3.3   1300
# 9                 2.7   2460
# 10                2.5   1096
# 11                3.4    499
# 12                3.2    563
# 13                4.7     52
# 14                4.9   2620
# 15                4.7    242
# 16                3.6    485
# 17                3.9   2639
# 18                3.7    706
# 19                3.8   2093
# 20                3.6    548
# 21                3.6    361
# 22                3.7    873
# 23                3.7    673
# 24                3.7    834
# 25                3.6    877
# 26                3.9   1503
# 27                3.9   3206
# 28                3.9    487
# 29                3.9   2003
# ..                ...    ...
# 92                0.0      2
# 93                4.4    840
# 94                4.0   2333
# 95                4.1   1821
# 96                4.1   3164
# 97                4.1    740
# 98                4.0    510
# 99                4.2    961
# 100               4.1    799
# 101               4.0    412
# 102               4.4   1942
# 103               4.0    312
# 104               4.0    361
# 105               4.3   1129
# 106               4.0    510
# 107               4.0    608
# 108               4.1   1959
# 109               4.0    817
# 110               4.1    400
# 111               4.3   5172
# 112               4.1    467
# 113               4.1   2417
# 114               4.1     90
# 115               4.3    104
# 116               4.0   2252
# 117               4.1   1838
# 118               4.0   1758
# 119               4.3   1457
# 120               4.3   3591
# 121               4.1    492
#
#                                                  Split  Similarity
# 0                          NorthIndian Chinese Mughlai        0.33
# 1                      NorthIndian Continental Italian        1.00
# 2                                                 Cafe        0.00
# 3           FingerFood Continental NorthIndian Chinese        0.58
# 4                                                 Cafe        0.00
# 5                                  NorthIndian Chinese        0.41
# 6                                          NorthIndian        0.58
# 7              Chinese NorthIndian Mughlai Continental        0.58
# 8                                             FastFood        0.00
# 9              NorthIndian Chinese Italian Continental        0.87
# 10             NorthIndian Chinese Italian Continental        0.87
# 11                     SouthIndian NorthIndian Chinese        0.33
# 12                     NorthIndian Italian Continental        1.00
# 13                    Continental Italian Asian Indian        0.58
# 14                                            IceCream        0.00
# 15                                         NorthIndian        0.58
# 16                                         NorthIndian        0.58
# 17                                        Chinese Thai        0.00
# 18    Continental Mexican American Italian NorthIndian        0.77
# 19                                     Burger FastFood        0.00
# 20                            Burger Juices FingerFood        0.00
# 21                                                Cafe        0.00
# 22                                NorthIndian European        0.41
# 23                     Chinese Continental NorthIndian        0.67
# 24                     NorthIndian Continental Italian        1.00
# 25           NorthIndian Chinese Italian Mediterranean        0.58
# 26                                  Pizza Italian Cafe        0.33
# 27                                                Cafe        0.00
# 28                                            Cafe Tea        0.00
# 29                         Asian Japanese Chinese Thai        0.00
# ..                                                 ...         ...
# 92                                         NorthIndian        0.58
# 93                  NorthIndian Italian Asian American        0.58
# 94             NorthIndian Chinese Italian Continental        0.87
# 95             NorthIndian Chinese Continental Italian        0.87
# 96                                 NorthIndian Chinese        0.41
# 97                      Biryani NorthIndian Hyderabadi        0.33
# 98                                  Biryani Hyderabadi        0.00
# 99   NorthIndian Chinese Italian American MiddleEas...        0.52
# 100      Continental NorthIndian Chinese Mediterranean        0.58
# 101                                            Chinese        0.00
# 102                                       ModernIndian        0.00
# 103                                           Japanese        0.00
# 104                    HealthyFood Continental Italian        0.67
# 105           NorthIndian Mediterranean Asian FastFood        0.29
# 106      Continental Mediterranean Italian NorthIndian        0.87
# 107                           FastFood American Burger        0.00
# 108             Continental American Asian NorthIndian        0.58
# 109  Italian Mexican Continental NorthIndian Finger...        0.77
# 110                                  Asian NorthIndian        0.41
# 111                                        SouthIndian        0.00
# 112  Continental Mexican Burger American Pizza Tex-Mex        0.24
# 113                                               Cafe        0.00
# 114                               NorthIndian European        0.41
# 115                        NorthIndian Afghani Mughlai        0.33
# 116              Continental NorthIndian Italian Asian        0.87
# 117           NorthIndian European Asian Mediterranean        0.29
# 118                            NorthIndian Continental        0.82
# 119                           Bakery Desserts FastFood        0.00
# 120                           Bakery FastFood Desserts        0.00
# 121                                                  X        0.00
#
# [122 rows x 8 columns]

# %% [markdown]
# ### Applying Cosine Similarity

# %%
data_sample['Similarity'] = 0.0
X = 'NorthIndian Continental Italian'

X_list = set(word_tokenize(X))  
for i in range(0, data_sample.index[-1]):
    Y = data_sample['Split'][i]
    Y_list = set(word_tokenize(Y))
    
    l1 =[];l2 =[] 
    rvector = X_list.union(Y_list)
    
    for w in rvector: 
        if w in X_list: l1.append(1) # create a vector 
        else: l1.append(0) 
        if w in Y_list: l2.append(1) 
        else: l2.append(0) 
    c = 0
    
    for l in range(len(rvector)): 
        c+= l1[l]*l2[l] 
    cosine = c / float((sum(l1)*sum(l2))**0.5) 
    
    
    data_sample['Similarity'].iloc[i] = float(np.round(cosine, 2))
# Out:
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Top Restuarant Based on Cusisine Similarity

# %%
data_sample.sort_values('Similarity', ascending=False)
# Out:
#      index                      Restaurant Name  \
# 0     2999                                Amber
# 91    3090                      Ovenstory Pizza
# 89    3088                                 Zizo
# 88    3087                                  Zen
# 87    3086                              Zaffran
# 86    3085                       Warehouse Cafe
# 85    3084                                 Veda
# 84    3083                       The Vault Cafe
# 83    3082                    The Rolling Joint
# 82    3081     The Luggage Room Kitchen And Bar
# 81    3080                    The Junkyard Cafe
# 80    3079               The Flying Saucer Cafe
# 79    3078               The Beer Cafe - BIGGIE
# 78    3077                            Teddy Boy
# 77    3076                       Taste of China
# 76    3075                              Tamasha
# 75    3074                               Subway
# 74    3073                            Starbucks
# 73    3072                    SSKY Bar & Lounge
# 72    3071                  South Indian Snacks
# 71    3070                         Shake Square
# 70    3069                               Sbarro
# 69    3068                             Route 04
# 68    3067            Rajdhani Thali Restaurant
# 67    3066  Quote - The Eclectic Bar and Lounge
# 66    3065                    Punjabi By Nature
# 65    3064                              Privee'
# 64    3063                         Playboy Cafe
# 63    3062                            Pizza Hut
# 90    3089                        Kettle & Kegs
# ..     ...                                  ...
# 30    3029                         China Garden
# 31    3030                           Desi Vibes
# 46    3045                            Kinbuck 2
# 58    3057                  Nizam's Kathi Kabab
# 57    3056                              Nando's
# 56    3055                  My Bar Headquarters
# 55    3054                     Mughlai Junction
# 54    3053                         Mother India
# 53    3052                        Moets Arabica
# 52    3051                           McDonald's
# 51    3050                           McDonald's
# 50    3049                   Lord of the Drinks
# 49    3048                           Life Caffe
# 48    3047                            Lady Baga
# 47    3046                         La Americana
# 45    3044                          Khan Chacha
# 32    3031                       Domino's Pizza
# 44    3043                                  KFC
# 43    3042                         Kebab Xpress
# 42    3041                        Kake Da Hotel
# 41    3040                      Jungle Jamboree
# 40    3039                     Jain Chawal Wale
# 39    3038                 Indian Grill Company
# 38    3037                           Haldiram's
# 37    3036                            GoGourmet
# 36    3035                             FLYP@MTV
# 35    3034                              Embassy
# 34    3033                       Dunkin' Donuts
# 33    3032                       Dunkin' Donuts
# 121   3120                 {Niche} - Cafe & Bar
#
#                                               Cuisines         Locality  \
# 0                       North Indian, Chinese, Mughlai  Connaught Place
# 91                                    Pizza, Fast Food  Connaught Place
# 89    Lebanese, Mediterranean, Middle Eastern, Arabian  Connaught Place
# 88                 Chinese, Japanese, Italian, Seafood  Connaught Place
# 87                               North Indian, Mughlai  Connaught Place
# 86   American, Continental, Italian, North Indian, ...  Connaught Place
# 85                               North Indian, Mughlai  Connaught Place
# 84     North Indian, Mediterranean, Asian, Continental  Connaught Place
# 83                                           Fast Food  Connaught Place
# 82                North Indian, Continental, Fast Food  Connaught Place
# 81                  North Indian, Mediterranean, Asian  Connaught Place
# 80   Italian, Mediterranean, Continental, North Indian  Connaught Place
# 79                  Finger Food, North Indian, Italian  Connaught Place
# 78              North Indian, Continental, Finger Food  Connaught Place
# 77                                       Chinese, Thai  Connaught Place
# 76     Finger Food, North Indian, Continental, Italian  Connaught Place
# 75            American, Fast Food, Salad, Healthy Food  Connaught Place
# 74                                                Cafe  Connaught Place
# 73                      Mughlai, North Indian, Chinese  Connaught Place
# 72                                        South Indian  Connaught Place
# 71                                Beverages, Fast Food  Connaught Place
# 70                                      Pizza, Italian  Connaught Place
# 69        Continental, American, Tex-Mex, North Indian  Connaught Place
# 68                                Gujarati, Rajasthani  Connaught Place
# 67                 Finger Food, European, North Indian  Connaught Place
# 66                               North Indian, Mughlai  Connaught Place
# 65         Chinese, Italian, Continental, North Indian  Connaught Place
# 64                  North Indian, Chinese, Continental  Connaught Place
# 63                           Italian, Pizza, Fast Food  Connaught Place
# 90                                                 Tea  Connaught Place
# ..                                                 ...              ...
# 30                                             Chinese  Connaught Place
# 31                               North Indian, Mughlai  Connaught Place
# 46   North Indian, Italian, Mexican, Chettinad, Chi...  Connaught Place
# 58                             North Indian, Fast Food  Connaught Place
# 57                                 Portuguese, African  Connaught Place
# 56                      North Indian, Mughlai, Chinese  Connaught Place
# 55                               North Indian, Mughlai  Connaught Place
# 54        Bengali, South Indian, North Indian, Mughlai  Connaught Place
# 53                                    Arabian, Mexican  Connaught Place
# 52                                   Fast Food, Burger  Connaught Place
# 51                                   Fast Food, Burger  Connaught Place
# 50            European, Chinese, North Indian, Italian  Connaught Place
# 49    Cafe, North Indian, Italian, Japanese, Fast Food  Connaught Place
# 48                                       Goan, Seafood  Connaught Place
# 47                                   Fast Food, Burger  Connaught Place
# 45                               Mughlai, North Indian  Connaught Place
# 32                                    Pizza, Fast Food  Connaught Place
# 44                                 American, Fast Food  Connaught Place
# 43                               North Indian, Mughlai  Connaught Place
# 42                                        North Indian  Connaught Place
# 41   North Indian, Continental, Chinese, Italian, T...  Connaught Place
# 40                                        North Indian  Connaught Place
# 39                           North Indian, Continental  Connaught Place
# 38   Street Food, North Indian, South Indian, Chine...  Connaught Place
# 37                             Healthy Food, Beverages  Connaught Place
# 36         North Indian, Mexican, Italian, Continental  Connaught Place
# 35                 North Indian, Continental, European  Connaught Place
# 34                         Burger, Desserts, Fast Food  Connaught Place
# 33                         Burger, Desserts, Fast Food  Connaught Place
# 121        North Indian, Chinese, Italian, Continental  Connaught Place
#
#      Aggregate rating  Votes  \
# 0                 2.6    152
# 91                0.0      0
# 89                3.9   1071
# 88                3.5   1027
# 87                3.9    908
# 86                3.7   4914
# 85                3.9   1087
# 84                3.9   3413
# 83                3.9    783
# 82                3.5     63
# 81                3.9   1545
# 80                3.9    143
# 79                3.8    645
# 78                3.9   1020
# 77                3.5    327
# 76                3.7   1801
# 75                3.5    276
# 74                3.8    552
# 73                3.5     92
# 72                3.6     50
# 71                3.7   1333
# 70                3.5   1311
# 69                3.5   1863
# 68                3.6   1134
# 67                3.5    422
# 66                3.7   1256
# 65                3.6     61
# 64                3.7    140
# 63                3.5    541
# 90                0.0      0
# ..                ...    ...
# 30                3.9    496
# 31                3.9    841
# 46                3.9   1286
# 58                3.8   1761
# 57                3.7   1891
# 56                3.7   3010
# 55                3.9    310
# 54                3.9     66
# 53                3.5     95
# 52                3.7    108
# 51                3.8    388
# 50                3.9   2589
# 49                3.6    391
# 48                3.7    277
# 47                3.7     41
# 45                3.7   1189
# 32                3.7    336
# 44                3.7    427
# 43                3.5    321
# 42                3.5   2185
# 41                3.8   1174
# 40                3.8    301
# 39                3.7    626
# 38                3.9   1151
# 37                3.7     55
# 36                3.9   1379
# 35                3.5    706
# 34                3.9   1607
# 33                3.8    271
# 121               4.1    492
#
#                                                  Split  Similarity
# 0                          NorthIndian Chinese Mughlai         0.0
# 91                                      Pizza FastFood         0.0
# 89        Lebanese Mediterranean MiddleEastern Arabian         0.0
# 88                    Chinese Japanese Italian Seafood         0.0
# 87                                 NorthIndian Mughlai         0.0
# 86      American Continental Italian NorthIndian Asian         0.0
# 85                                 NorthIndian Mughlai         0.0
# 84         NorthIndian Mediterranean Asian Continental         0.0
# 83                                            FastFood         0.0
# 82                    NorthIndian Continental FastFood         0.0
# 81                     NorthIndian Mediterranean Asian         0.0
# 80       Italian Mediterranean Continental NorthIndian         0.0
# 79                      FingerFood NorthIndian Italian         0.0
# 78                  NorthIndian Continental FingerFood         0.0
# 77                                        Chinese Thai         0.0
# 76          FingerFood NorthIndian Continental Italian         0.0
# 75                 American FastFood Salad HealthyFood         0.0
# 74                                                Cafe         0.0
# 73                         Mughlai NorthIndian Chinese         0.0
# 72                                         SouthIndian         0.0
# 71                                  Beverages FastFood         0.0
# 70                                       Pizza Italian         0.0
# 69            Continental American Tex-Mex NorthIndian         0.0
# 68                                 Gujarati Rajasthani         0.0
# 67                     FingerFood European NorthIndian         0.0
# 66                                 NorthIndian Mughlai         0.0
# 65             Chinese Italian Continental NorthIndian         0.0
# 64                     NorthIndian Chinese Continental         0.0
# 63                              Italian Pizza FastFood         0.0
# 90                                                 Tea         0.0
# ..                                                 ...         ...
# 30                                             Chinese         0.0
# 31                                 NorthIndian Mughlai         0.0
# 46   NorthIndian Italian Mexican Chettinad Chinese ...         0.0
# 58                                NorthIndian FastFood         0.0
# 57                                  Portuguese African         0.0
# 56                         NorthIndian Mughlai Chinese         0.0
# 55                                 NorthIndian Mughlai         0.0
# 54             Bengali SouthIndian NorthIndian Mughlai         0.0
# 53                                     Arabian Mexican         0.0
# 52                                     FastFood Burger         0.0
# 51                                     FastFood Burger         0.0
# 50                European Chinese NorthIndian Italian         0.0
# 49          Cafe NorthIndian Italian Japanese FastFood         0.0
# 48                                        Goan Seafood         0.0
# 47                                     FastFood Burger         0.0
# 45                                 Mughlai NorthIndian         0.0
# 32                                      Pizza FastFood         0.0
# 44                                   American FastFood         0.0
# 43                                 NorthIndian Mughlai         0.0
# 42                                         NorthIndian         0.0
# 41   NorthIndian Continental Chinese Italian Thai M...         0.0
# 40                                         NorthIndian         0.0
# 39                             NorthIndian Continental         0.0
# 38   StreetFood NorthIndian SouthIndian Chinese Mithai         0.0
# 37                               HealthyFood Beverages         0.0
# 36             NorthIndian Mexican Italian Continental         0.0
# 35                    NorthIndian Continental European         0.0
# 34                            Burger Desserts FastFood         0.0
# 33                            Burger Desserts FastFood         0.0
# 121                                                  X         0.0
#
# [122 rows x 8 columns]
