# %% [markdown]
# ## Simple Recommdation System

# %%
## Importing Files
import numpy as np 
import pandas as pd 
import re

# %%
## Loading Data 
data = pd.read_csv('/home/student/Desktop/Practise_Folder/Project/Data/zomatoNCR.csv', encoding ='latin1')
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
## Extracting Delhi NCR Data
res_India = data
NCR = ['New Delhi','Gurgaon','Noida','Faridabad']
res_NCR = res_India[(res_India.City == NCR[0])|(res_India.City == NCR[1])|(res_India.City == NCR[2])|
                    (res_India.City == NCR[3])]

res_NCR.shape
# Out:
# (7922, 21)

# %%
## Regularizing Predicting Parameters --(Rating and Voting) 
data_new_delphi=res_NCR[['Restaurant Name','Cuisines','Locality','Aggregate rating', 'Votes']] #--Extracting Columns


C = data_new_delphi['Aggregate rating'].mean()
m = data_new_delphi['Votes'].quantile(0.90) #--Quantile

# Filter out all qualified restaurants into a new DataFrame
q_restaurant = data_new_delphi.copy().loc[data_new_delphi['Votes'] >= m]
q_restaurant.shape
# Out:
# (795, 5)

# %%
# Function that computes the weighted rating of each restaurant
def weighted_rating(x, m=m, C=C):
    v = x['Votes']
    R = x['Aggregate rating']
    # Calculating the score
    return np.round((v/(v+m) * R) + (m/(m+v) * C))
# Define a new feature 'score' and calculate its value with `weighted_rating()`
q_restaurant['score'] = q_restaurant.apply(weighted_rating, axis=1)

# %%
#Sort restaurant based on score calculated above
q_restaurant = q_restaurant.sort_values('score', ascending=False)

# %%
#Print the top 10 restaurants in Delhi NCR
q_restaurant[['Restaurant Name','Cuisines', 'Locality','Votes', 'Aggregate rating', 'score']].head(10)
# Out:
#                 Restaurant Name  \
# 3013         Naturals Ice Cream
# 3601  Indian Accent - The Manor
# 6997        Echoes Satyaniketan
# 6461            The Coffee Shop
# 3040            Jungle Jamboree
# 3732                     Tashan
# 7067                   Pa Pa Ya
# 3037                 Haldiram's
# 3035                   FLYP@MTV
# 7045              Wood Box Cafe
#
#                                                Cuisines  \
# 3013                                          Ice Cream
# 3601                                      Modern Indian
# 6997  Cafe, Continental, Italian, Mexican, Chinese, ...
# 6461                                      Cafe, Italian
# 3040  North Indian, Continental, Chinese, Italian, T...
# 3732                                      Modern Indian
# 7067                     Asian, Chinese, Thai, Japanese
# 3037  Street Food, North Indian, South Indian, Chine...
# 3035        North Indian, Mexican, Italian, Continental
# 7045                  Cafe, Fast Food, Italian, Chinese
#
#                          Locality  Votes  Aggregate rating  score
# 3013              Connaught Place   2620               4.9    5.0
# 3601               Friends Colony   1934               4.9    5.0
# 6997                 Satyaniketan   1563               4.7    4.0
# 6461           PVR Anupam Complex    326               4.4    4.0
# 3040              Connaught Place   1174               3.8    4.0
# 3732       Greater Kailash (GK) 2    304               4.6    4.0
# 7067  Select Citywalk Mall, Saket    268               4.7    4.0
# 3037              Connaught Place   1151               3.9    4.0
# 3035              Connaught Place   1379               3.9    4.0
# 7045                 Satyaniketan   1479               4.1    4.0

# %% [markdown]
# ## Content-Based Recommender

# %%
## Importing Files
import numpy as np 
import pandas as pd 
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from nltk.tokenize import word_tokenize

# %%
## Loading Data --1235
data = pd.read_csv('/home/student/Desktop/Practise_Folder/Project/Data/zomatoNCR.csv', encoding ='latin1')
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
data_city =data.loc[data['City'] == 'New Delhi']
data_new_delhi=data_city[['Restaurant Name','Cuisines','Locality','Aggregate rating']]
data_new_delhi.loc[data['Locality'] == 'Connaught Place']
# Out:
#                  Restaurant Name  \
# 2999                       Amber
# 3000      Attitude Kitchen & Bar
# 3001             Cafe Coffee Day
# 3002                    Castle 9
# 3003                Costa Coffee
# 3004          Delhi Darbar Dhaba
# 3005                Garam Dharam
# 3006               Gola Sizzlers
# 3007         Indian Coffee House
# 3008  My Bar Lounge & Restaurant
# 3009               My Bar Square
# 3010                 Sagar Ratna
# 3011          The Immigrant Cafe
# 3012                 MOB Brewpub
# 3013          Naturals Ice Cream
# 3014    Zabardast Indian Kitchen
# 3015            Anand Restaurant
# 3016                     Berco's
# 3017                       Blues
# 3018                 Burger King
# 3019                Burger Singh
# 3020  Cafe Coffee Day The Square
# 3021           Cafe Dalal Street
# 3022                Cafe Hawkers
# 3023      Cafe Public Connection
# 3024                  Cafï¿½ MRP
# 3025                Caffe Tonino
# 3026                     Cha Bar
# 3027                     Chaayos
# 3028       Chew - Pan Asian Cafe
# ...                          ...
# 3091   Shree Hari Vaishnav Dhaba
# 3092                 38 Barracks
# 3093              Ambrosia Bliss
# 3094                   Ardor 2.1
# 3095             Barbeque Nation
# 3096            Bikkgane Biryani
# 3097               Biryani Blues
# 3098                     Caffe 9
# 3099              Excuse Me Boss
# 3100                     Fa Yian
# 3101                  Farzi Cafe
# 3102    Fuji Japanese Restaurant
# 3103              Healthy Routes
# 3104                     HotMess
# 3105            House of Commons
# 3106              Johnny Rockets
# 3107                Odeon Social
# 3108               Pebble Street
# 3109    Piali - The Curry Bistro
# 3110             Saravana Bhavan
# 3111              Smoke On Water
# 3112                   Starbucks
# 3113     The Darzi Bar & Kitchen
# 3114               The G.T. Road
# 3115         The Town House Cafe
# 3116         United Coffee House
# 3117         Unplugged Courtyard
# 3118               Wenger's Deli
# 3119                    Wenger's
# 3120        {Niche} - Cafe & Bar
#
#                                                Cuisines         Locality  \
# 2999                     North Indian, Chinese, Mughlai  Connaught Place
# 3000                 North Indian, Continental, Italian  Connaught Place
# 3001                                               Cafe  Connaught Place
# 3002    Finger Food, Continental, North Indian, Chinese  Connaught Place
# 3003                                               Cafe  Connaught Place
# 3004                              North Indian, Chinese  Connaught Place
# 3005                                       North Indian  Connaught Place
# 3006        Chinese, North Indian, Mughlai, Continental  Connaught Place
# 3007                                          Fast Food  Connaught Place
# 3008        North Indian, Chinese, Italian, Continental  Connaught Place
# 3009        North Indian, Chinese, Italian, Continental  Connaught Place
# 3010                South Indian, North Indian, Chinese  Connaught Place
# 3011                 North Indian, Italian, Continental  Connaught Place
# 3012                Continental, Italian, Asian, Indian  Connaught Place
# 3013                                          Ice Cream  Connaught Place
# 3014                                       North Indian  Connaught Place
# 3015                                       North Indian  Connaught Place
# 3016                                      Chinese, Thai  Connaught Place
# 3017  Continental, Mexican, American, Italian, North...  Connaught Place
# 3018                                  Burger, Fast Food  Connaught Place
# 3019                        Burger, Juices, Finger Food  Connaught Place
# 3020                                               Cafe  Connaught Place
# 3021                             North Indian, European  Connaught Place
# 3022                 Chinese, Continental, North Indian  Connaught Place
# 3023                 North Indian, Continental, Italian  Connaught Place
# 3024      North Indian, Chinese, Italian, Mediterranean  Connaught Place
# 3025                               Pizza, Italian, Cafe  Connaught Place
# 3026                                               Cafe  Connaught Place
# 3027                                          Cafe, Tea  Connaught Place
# 3028                     Asian, Japanese, Chinese, Thai  Connaught Place
# ...                                                 ...              ...
# 3091                                       North Indian  Connaught Place
# 3092             North Indian, Italian, Asian, American  Connaught Place
# 3093        North Indian, Chinese, Italian, Continental  Connaught Place
# 3094        North Indian, Chinese, Continental, Italian  Connaught Place
# 3095                              North Indian, Chinese  Connaught Place
# 3096                  Biryani, North Indian, Hyderabadi  Connaught Place
# 3097                                Biryani, Hyderabadi  Connaught Place
# 3098  North Indian, Chinese, Italian, American, Midd...  Connaught Place
# 3099  Continental, North Indian, Chinese, Mediterranean  Connaught Place
# 3100                                            Chinese  Connaught Place
# 3101                                      Modern Indian  Connaught Place
# 3102                                           Japanese  Connaught Place
# 3103                 Healthy Food, Continental, Italian  Connaught Place
# 3104      North Indian, Mediterranean, Asian, Fast Food  Connaught Place
# 3105  Continental, Mediterranean, Italian, North Indian  Connaught Place
# 3106                        Fast Food, American, Burger  Connaught Place
# 3107         Continental, American, Asian, North Indian  Connaught Place
# 3108  Italian, Mexican, Continental, North Indian, F...  Connaught Place
# 3109                                Asian, North Indian  Connaught Place
# 3110                                       South Indian  Connaught Place
# 3111  Continental, Mexican, Burger, American, Pizza,...  Connaught Place
# 3112                                               Cafe  Connaught Place
# 3113                             North Indian, European  Connaught Place
# 3114                     North Indian, Afghani, Mughlai  Connaught Place
# 3115          Continental, North Indian, Italian, Asian  Connaught Place
# 3116       North Indian, European, Asian, Mediterranean  Connaught Place
# 3117                          North Indian, Continental  Connaught Place
# 3118                        Bakery, Desserts, Fast Food  Connaught Place
# 3119                        Bakery, Fast Food, Desserts  Connaught Place
# 3120        North Indian, Chinese, Italian, Continental  Connaught Place
#
#       Aggregate rating
# 2999               2.6
# 3000               2.9
# 3001               3.4
# 3002               3.1
# 3003               3.4
# 3004               3.2
# 3005               3.4
# 3006               3.0
# 3007               3.3
# 3008               2.7
# 3009               2.5
# 3010               3.4
# 3011               3.2
# 3012               4.7
# 3013               4.9
# 3014               4.7
# 3015               3.6
# 3016               3.9
# 3017               3.7
# 3018               3.8
# 3019               3.6
# 3020               3.6
# 3021               3.7
# 3022               3.7
# 3023               3.7
# 3024               3.6
# 3025               3.9
# 3026               3.9
# 3027               3.9
# 3028               3.9
# ...                ...
# 3091               0.0
# 3092               4.4
# 3093               4.0
# 3094               4.1
# 3095               4.1
# 3096               4.1
# 3097               4.0
# 3098               4.2
# 3099               4.1
# 3100               4.0
# 3101               4.4
# 3102               4.0
# 3103               4.0
# 3104               4.3
# 3105               4.0
# 3106               4.0
# 3107               4.1
# 3108               4.0
# 3109               4.1
# 3110               4.3
# 3111               4.1
# 3112               4.1
# 3113               4.1
# 3114               4.3
# 3115               4.0
# 3116               4.1
# 3117               4.0
# 3118               4.3
# 3119               4.3
# 3120               4.1
#
# [122 rows x 4 columns]

# %%
data_sample=[]

def restaurant_recommend_func(location,title):   
    global data_sample       
    global cosine_sim
    global sim_scores
    global tfidf_matrix
    global corpus_index
    global feature
    global rest_indices
    global idx
    
    data_sample = data_new_delphi.loc[data_new_delphi['Locality'] == location]  
    
    data_sample.reset_index(level=0, inplace=True) 
    
    data_sample['Split']="X"
    for i in range(0,data_sample.index[-1]):
        split_data=re.split(r'[,]', data_sample['Cuisines'][i])
        for k,l in enumerate(split_data):
            split_data[k]=(split_data[k].replace(" ", ""))
        split_data=' '.join(split_data[:])
        data_sample['Split'].iloc[i]=split_data
        
    tfidf = TfidfVectorizer(stop_words='english')
    data_sample['Split'] = data_sample['Split'].fillna('')
    tfidf_matrix = tfidf.fit_transform(data_sample['Split'])
    tfidf_matrix.shape
    
    feature= tfidf.get_feature_names()
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix) 
    
    corpus_index=[n for n in data_sample['Split']]
       
    indices = pd.Series(data_sample.index, index=data_sample['Restaurant Name']).drop_duplicates() 
    
    idx = indices[title]
    sim_scores=[]
    for i,j in enumerate(cosine_sim[idx]):
        k=data_sample['Aggregate rating'].iloc[i]
        if j != 0 :
            sim_scores.append((i,j,k))
            
    sim_scores = sorted(sim_scores, key=lambda x: (x[1],x[2]) , reverse=True)
    sim_scores = sim_scores[0:10]
    rest_indices = [i[0] for i in sim_scores] 
  
    data_x =data_sample[['Restaurant Name','Aggregate rating']].iloc[rest_indices]
    
    data_x['Cosine Similarity']=0
    for i,j in enumerate(sim_scores):
        data_x['Cosine Similarity'].iloc[i]=round(sim_scores[i][1],2)
   
    return data_x

restaurant_recommend_func('Connaught Place','Pizza Hut')
# Out:
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/student/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                      Restaurant Name  Aggregate rating  Cosine Similarity
# 63                         Pizza Hut               3.5               1.00
# 32                    Domino's Pizza               3.7               0.90
# 91                   Ovenstory Pizza               0.0               0.90
# 70                            Sbarro               3.5               0.86
# 26                      Caffe Tonino               3.9               0.68
# 83                 The Rolling Joint               3.9               0.52
# 8                Indian Coffee House               3.3               0.52
# 58               Nizam's Kathi Kabab               3.8               0.45
# 82  The Luggage Room Kitchen And Bar               3.5               0.36
# 49                        Life Caffe               3.6               0.36

# %% [markdown]
#    ## Rough Work

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

data_sample=[]
data_sample = data_new_delphi.loc[data_new_delphi['Locality'] == 'Connaught Place']
data_sample.reset_index(level=0, inplace=True) 
data_sample
# Out:
#      index             Restaurant Name  \
# 0     2999                       Amber
# 1     3000      Attitude Kitchen & Bar
# 2     3001             Cafe Coffee Day
# 3     3002                    Castle 9
# 4     3003                Costa Coffee
# 5     3004          Delhi Darbar Dhaba
# 6     3005                Garam Dharam
# 7     3006               Gola Sizzlers
# 8     3007         Indian Coffee House
# 9     3008  My Bar Lounge & Restaurant
# 10    3009               My Bar Square
# 11    3010                 Sagar Ratna
# 12    3011          The Immigrant Cafe
# 13    3012                 MOB Brewpub
# 14    3013          Naturals Ice Cream
# 15    3014    Zabardast Indian Kitchen
# 16    3015            Anand Restaurant
# 17    3016                     Berco's
# 18    3017                       Blues
# 19    3018                 Burger King
# 20    3019                Burger Singh
# 21    3020  Cafe Coffee Day The Square
# 22    3021           Cafe Dalal Street
# 23    3022                Cafe Hawkers
# 24    3023      Cafe Public Connection
# 25    3024                  Cafï¿½ MRP
# 26    3025                Caffe Tonino
# 27    3026                     Cha Bar
# 28    3027                     Chaayos
# 29    3028       Chew - Pan Asian Cafe
Continental, Mexican, Burger, American, Pizza,...  Connaught Place
# 113                                               Cafe  Connaught Place
# 114                             North Indian, European  Connaught Place
# 115                     North Indian, Afghani, Mughlai  Connaught Place
# 116          Continental, North Indian, Italian, Asian  Connaught Place
# 117       North Indian, European, Asian, Mediterranean  Connaught Place
# 118                          North Indian, Continental  Connaught Place
# 119                        Bakery, Desserts, Fast Food  Connaught Place
# 120                        Bakery, Fast Food, Desserts  Connaught Place
# 121        North Indian, Chinese, Italian, Continental  Connaught Place
#
#      Aggregate rating
# 0                 2.6
# 1                 2.9
# 2                 3.4
# 3                 3.1
# 4                 3.4
# 5                 3.2
# 6                 3.4
# 7                 3.0
# 8                 3.3
# 9                 2.7
# 10                2.5
# 11                3.4
# 12                3.2
# 13                4.7
# 14                4.9
# 15                4.7
# 16                3.6
# 17                3.9
# 18                3.7
# 19                3.8
# 20                3.6
# 21                3.6
# 22                3.7
# 23                3.7
# 24                3.7
# 25                3.6
# 26                3.9
# 27                3.9
# 28                3.9
# 29                3.9
# ..                ...
# 92                0.0
# 93                4.4
# 94                4.0
# 95                4.1
# 96                4.1
# 97                4.1
# 98                4.0
# 99                4.2
# 100               4.1
# 101               4.0
# 102               4.4
# 103               4.0
# 104               4.0
# 105               4.3
# 106               4.0
# 107               4.0
# 108               4.1
# 109               4.0
# 110               4.1
# 111               4.3
# 112               4.1
# 113               4.1
# 114               4.1
# 115               4.3
# 116               4.0
# 117               4.1
# 118               4.0
# 119               4.3
# 120               4.3
# 121               4.1
#
# [122 rows x 5 columns]

# %%
data_sample['Split']="X"
data_sample
# Out:
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      index             Restaurant Name  \
# 0     2999                       Amber
# 1     3000      Attitude Kitchen & Bar
# 2     3001             Cafe Coffee Day
# 3     3002                    Castle 9
# 4     3003                Costa Coffee
# 5     3004          Delhi Darbar Dhaba
# 6     3005                Garam Dharam
# 7     3006               Gola Sizzlers
# 8     3007         Indian Coffee House
# 9     3008  My Bar Lounge & Restaurant
# 10    3009               My Bar Square
# 11    3010                 Sagar Ratna
# 12    3011          The Immigrant Cafe
# 13    3012                 MOB Brewpub
# 14    3013          Naturals Ice Cream
# 15    3014    Zabardast Indian Kitchen
# 16    3015            Anand Restaurant
# 17    3016                     Berco's
# 18    3017                       Blues
# 19    3018                 Burger King
# 20    3019                Burger Singh
# 21    3020  Cafe Coffee Day The Square
# 22    3021           Cafe Dalal Street
# 23    3022                Cafe Hawkers
# 24    3023      Cafe Public Connection
# 25    3024                  Cafï¿½ MRP
# 26    3025                Caffe Tonino
# 27    3026                     Cha Bar
# 28    3027                     Chaayos
# 29    3028       Chew - Pan Asian Cafe
# ..     ...                         ...
# 92    3091   Shree Hari Vaishnav Dhaba
# 93    3092                 38 Barracks
# 94    3093              Ambrosia Bliss
# 95    3094                   Ardor 2.1
# 96    3095             Barbeque Nation
# 97    3096            Bikkgane Biryani
# 98    3097               Biryani Blues
# 99    3098                     Caffe 9
# 100   3099              Excuse Me Boss
# 101   3100                     Fa Yian
# 102   3101                  Farzi Cafe
# 103   3102    Fuji Japanese Restaurant
# 104   3103              Healthy Routes
# 105   3104                     HotMess
# 106   3105            House of Commons
# 107   3106              Johnny Rockets
# 108   3107                Odeon Social
# 109   3108               Pebble Street
# 110   3109    Piali - The Curry Bistro
# 111   3110             Saravana Bhavan
# 112   3111              Smoke On Water
# 113   3112                   Starbucks
# 114   3113     The Darzi Bar & Kitchen
# 115   3114               The G.T. Road
# 116   3115         The Town House Cafe
# 117   3116         United Coffee House
# 118   3117         Unplugged Courtyard
# 119   3118               Wenger's Deli
# 120   3119                    Wenger's
# 121   3120        {Niche} - Cafe & Bar
#
#                                               Cuisines         Locality  \
# 0                       North Indian, Chinese, Mughlai  Connaught Place
#
Connaught Place
# 121        North Indian, Chinese, Italian, Continental  Connaught Place
#
#      Aggregate rating Split
# 0                 2.6     X
# 1                 2.9     X
# 2                 3.4     X
# 3                 3.1     X
# 4                 3.4     X
# 5                 3.2     X
# 6                 3.4     X
# 7                 3.0     X
# 8                 3.3     X
# 9                 2.7     X
# 10                2.5     X
# 11                3.4     X
# 12                3.2     X
# 13                4.7     X
# 14                4.9     X
# 15                4.7     X
# 16                3.6     X
# 17                3.9     X
# 18                3.7     X
# 19                3.8     X
# 20                3.6     X
# 21                3.6     X
# 22                3.7     X
# 23                3.7     X
# 24                3.7     X
# 25                3.6     X
# 26                3.9     X
# 27                3.9     X
# 28                3.9     X
# 29                3.9     X
# ..                ...   ...
# 92                0.0     X
# 93                4.4     X
# 94                4.0     X
# 95                4.1     X
# 96                4.1     X
# 97                4.1     X
# 98                4.0     X
# 99                4.2     X
# 100               4.1     X
# 101               4.0     X
# 102               4.4     X
# 103               4.0     X
# 104               4.0     X
# 105               4.3     X
# 106               4.0     X
# 107               4.0     X
# 108               4.1     X
# 109               4.0     X
# 110               4.1     X
# 111               4.3     X
# 112               4.1     X
# 113               4.1     X
# 114               4.1     X
# 115               4.3     X
# 116               4.0     X
# 117               4.1     X
# 118               4.0     X
# 119               4.3     X
# 120               4.3     X
# 121               4.1     X
#
# [122 rows x 6 columns]

# %%
for i in range(0,data_sample.index[-1]):
        split_data=re.split(r'[,]', data_sample['Cuisines'][i])
        for k,l in enumerate(split_data):
            split_data[k]=(split_data[k].replace(" ", ""))
        split_data=' '.join(split_data[:])
        data_sample['Split'].iloc[i]=split_data
        
data_sample
# Out:
# /home/student/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      index             Restaurant Name  \
# 0     2999                       Amber
# 1     3000      Attitude Kitchen & Bar
# 2     3001             Cafe Coffee Day
# 3     3002                    Castle 9
# 4     3003                Costa Coffee
# 5     3004          Delhi Darbar Dhaba
# 6     3005                Garam Dharam
# 7     3006               Gola Sizzlers
# 8     3007         Indian Coffee House
# 9     3008  My Bar Lounge & Restaurant
# 10    3009               My Bar Square
# 11    3010                 Sagar Ratna
# 12    3011          The Immigrant Cafe
# 13    3012                 MOB Brewpub
# 14    3013          Naturals Ice Cream
# 15    3014    Zabardast Indian Kitchen
# 16    3015            Anand Restaurant
# 17    3016                     Berco's
# 18    3017                       Blues
# 19    3018                 Burger King
# 20    3019                Burger Singh
# 21    3020  Cafe Coffee Day The Square
# 22    3021           Cafe Dalal Street
# 23    3022                Cafe Hawkers
# 24    3023      Cafe Public Connection
# 25    3024                  Cafï¿½ MRP
# 26    3025                Caffe Tonino
# 27    3026                     Cha Bar
# 28    3027                     Chaayos
# 29    3028       Chew - Pan Asian Cafe
# ..     ...                         ...
# 92    3091   Shree Hari Vaishnav Dhaba
# 93    3092                 38 Barracks
# 94    3093              Ambrosia Bliss
# 95    3094                   Ardor 2.1
# 96    3095             Barbeque Nation
# 97    3096            Bikkgane Biryani
# 98    3097               Biryani Blues
# 99    3098                     Caffe 9
# 100   3099              Excuse Me Boss
# 101   3100                     Fa Yian
# 102   3101                  Farzi Cafe
# 103   3102    Fuji Japanese Restaurant
# 104   3103              Healthy Routes
# 105   3104                     HotMess
# 106   3105            House of Commons
# 107   3106              Johnny Rockets
# 108   3107                Odeon Social
# 109   3108               Pebble Street
# 110   3109    Piali - The Curry Bistro
# 111   3110             Saravana Bhavan
# 112   3111              Smoke On Water
# 113   3112                   Starbucks
# 114   3113     The Darzi Bar & Kitchen
# 115   3114               The G.T. Road
# 116   3115         The Town House Cafe
# 117   3116         United Coffee House
# 118   3117         Unplugged Courtyard
# 119   3118               Wenger's Deli
# 120   3119                    Wenger's
# 121   3120        {Niche} - Cafe & Bar
#
#                                               Cuisines         Locality  \
# 0                       North Indian, Chinese, Mughlai  Connaught Place
#
# 12                3.2                    NorthIndian Italian Continental
# 13                4.7                   Continental Italian Asian Indian
# 14                4.9                                           IceCream
# 15                4.7                                        NorthIndian
# 16                3.6                                        NorthIndian
# 17                3.9                                       Chinese Thai
# 18                3.7   Continental Mexican American Italian NorthIndian
# 19                3.8                                    Burger FastFood
# 20                3.6                           Burger Juices FingerFood
# 21                3.6                                               Cafe
# 22                3.7                               NorthIndian European
# 23                3.7                    Chinese Continental NorthIndian
# 24                3.7                    NorthIndian Continental Italian
# 25                3.6          NorthIndian Chinese Italian Mediterranean
# 26                3.9                                 Pizza Italian Cafe
# 27                3.9                                               Cafe
# 28                3.9                                           Cafe Tea
# 29                3.9                        Asian Japanese Chinese Thai
# ..                ...                                                ...
# 92                0.0                                        NorthIndian
# 93                4.4                 NorthIndian Italian Asian American
# 94                4.0            NorthIndian Chinese Italian Continental
# 95                4.1            NorthIndian Chinese Continental Italian
# 96                4.1                                NorthIndian Chinese
# 97                4.1                     Biryani NorthIndian Hyderabadi
# 98                4.0                                 Biryani Hyderabadi
# 99                4.2  NorthIndian Chinese Italian American MiddleEas...
# 100               4.1      Continental NorthIndian Chinese Mediterranean
# 101               4.0                                            Chinese
# 102               4.4                                       ModernIndian
# 103               4.0                                           Japanese
# 104               4.0                    HealthyFood Continental Italian
# 105               4.3           NorthIndian Mediterranean Asian FastFood
# 106               4.0      Continental Mediterranean Italian NorthIndian
# 107               4.0                           FastFood American Burger
# 108               4.1             Continental American Asian NorthIndian
# 109               4.0  Italian Mexican Continental NorthIndian Finger...
# 110               4.1                                  Asian NorthIndian
# 111               4.3                                        SouthIndian
# 112               4.1  Continental Mexican Burger American Pizza Tex-Mex
# 113               4.1                                               Cafe
# 114               4.1                               NorthIndian European
# 115               4.3                        NorthIndian Afghani Mughlai
# 116               4.0              Continental NorthIndian Italian Asian
# 117               4.1           NorthIndian European Asian Mediterranean
# 118               4.0                            NorthIndian Continental
# 119               4.3                           Bakery Desserts FastFood
# 120               4.3                           Bakery FastFood Desserts
# 121               4.1                                                  X
#
# [122 rows x 6 columns]

# %%
data_sample['Similarity'] = 'Y'
X = 'NorthIndian Continental Italian'
X_list = set(word_tokenize(X))  
for i in range(0, 1):#data_sample.index[-1]):
    Y = data_sample['Split'][i]
    print(Y)
    Y_list = set(word_tokenize(Y))
    rvector = X_list.union(Y_list)
    
    for w in rvector: 
        if w in X_list: l1.append(1) # create a vector 
        else: l1.append(0) 
        if w in Y_list: l2.append(1) 
        else: l2.append(0) 
    c = 0
    
    for l in range(len(rvector)): 
        c+= l1[i]*l2[l] 
    cosine = c / float((sum(l1)*sum(l2))**0.5) 
    
    print(cosine)
    data_sample['Similarity'].iloc[i] = cosine
# Out:
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# NorthIndian Chinese Mughlai
# /home/student/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data
# 94                4.0            NorthIndian Chinese Italian Continental
# 95                4.1            NorthIndian Chinese Continental Italian
# 96                4.1                                NorthIndian Chinese
# 97                4.1                     Biryani NorthIndian Hyderabadi
# 98                4.0                                 Biryani Hyderabadi
# 99                4.2  NorthIndian Chinese Italian American MiddleEas...
# 100               4.1      Continental NorthIndian Chinese Mediterranean
# 101               4.0                                            Chinese
# 102               4.4                                       ModernIndian
# 103               4.0                                           Japanese
# 104               4.0                    HealthyFood Continental Italian
# 105               4.3           NorthIndian Mediterranean Asian FastFood
# 106               4.0      Continental Mediterranean Italian NorthIndian
# 107               4.0                           FastFood American Burger
# 108               4.1             Continental American Asian NorthIndian
# 109               4.0  Italian Mexican Continental NorthIndian Finger...
# 110               4.1                                  Asian NorthIndian
# 111               4.3                                        SouthIndian
# 112               4.1  Continental Mexican Burger American Pizza Tex-Mex
# 113               4.1                                               Cafe
# 114               4.1                               NorthIndian European
# 115               4.3                        NorthIndian Afghani Mughlai
# 116               4.0              Continental NorthIndian Italian Asian
# 117               4.1           NorthIndian European Asian Mediterranean
# 118               4.0                            NorthIndian Continental
# 119               4.3                           Bakery Desserts FastFood
# 120               4.3                           Bakery FastFood Desserts
# 121               4.1                                                  X
#
#      Similarity
# 0             0
# 1             0
# 2             0
# 3    0.00783212
# 4             0
# 5             0
# 6    0.00580585
# 7    0.00768265
# 8    0.00574258
# 9    0.00569973
# 10   0.00565758
# 11            0
# 12   0.00559017
# 13   0.00739968
# 14            0
# 15   0.00551377
# 16            0
# 17    0.0072948
# 18   0.00723392
# 19   0.00720167
# 20   0.00895075
# 21   0.00535352
# 22   0.00532997
# 23            0
# 24            0
# 25   0.00697953
# 26   0.00694106
# 27   0.00518985
# 28   0.00689033
# 29    0.0102669
# ..          ...
# 92   0.00388685
# 93            0
# 94   0.00384936
# 95            0
# 96            0
# 97    0.0050719
# 98   0.00505617
# 99   0.00628528
# 100           0
# 101  0.00374503
# 102   0.0037366
# 103           0
# 104  0.00371391
# 105           0
# 106   0.0036798
# 107   0.0061098
# 108  0.00486562
# 109  0.00483985
# 110  0.00361915
# 111  0.00361126
# 112           0
# 113           0
# 114  0.00357138
# 115  0.00474439
# 116  0.00354263
# 117           0
# 118  0.00351697
# 119           0
# 120   0.0058195
# 121           Y
#
# [122 rows x 7 columns]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
# X = input("Enter first string: ").lower() 
# Y = input("Enter second string: ").lower() 
X ="NorthIndian Continental Italian"
Y ="NorthIndian Continental Italian"
  
# tokenization 
X_list = word_tokenize(X)  
Y_list = word_tokenize(Y) 
  
# sw contains the list of stopwords 
sw = stopwords.words('english')  
l1 =[];l2 =[] 
  
# remove stop words from string 
X_set = {w for w in X_list if not w in sw}  
Y_set = {w for w in Y_list if not w in sw} 
  
# form a set containing keywords of both strings  
rvector = X_set.union(Y_set)  
for w in rvector: 
    if w in X_set: l1.append(1) # create a vector 
    else: l1.append(0) 
    if w in Y_set: l2.append(1) 
    else: l2.append(0) 
c = 0
  
# cosine formula  
for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
cosine = c / float((sum(l1)*sum(l2))**0.5) 
print("similarity: ", cosine)
# Out:
# similarity:  1.0
